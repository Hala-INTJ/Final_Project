# %%
# Import dependencies
import pandas as pd
from sqlalchemy import create_engine
import time

# %%
# Connecting to the Database
engine = create_engine("postgresql://postgres:postgres@localhost/WWTP")
conn = engine.connect()

# Reading SQL query into a Dataframe 
df_temp1 = pd.read_sql_query('select * from "temp_1"', con=conn)
df_temp2 = pd.read_sql_query('select * from "Influent_temp_2"', con=conn)

# %%
# Selecting specific columns
df_temp1 = df_temp1[['Time', 'T0-S0-INF-INF-Flow']]

# %%
# Merging Dataframes
df = pd.merge(df_temp1, df_temp2, on='Time', how='outer')
df
# Out:
#            Time  T0-S0-INF-INF-Flow  T0-S0-INF-TSS  T0-S0-INF-TP  \
# 0    2017-01-01                 NaN            NaN           NaN
# 1    2017-01-02                 NaN            NaN           NaN
# 2    2017-01-03                 NaN     208.000000      6.850000
# 3    2017-01-04                 NaN     274.000000      5.210000
# 4    2017-01-05                 NaN     229.000000      4.890000
# ...         ...                 ...            ...           ...
# 1587 2021-05-07            328403.6     274.323706      6.634315
# 1588 2021-05-08            336397.7     256.967409      6.281964
# 1589 2021-05-09            336416.8     249.500000      5.960000
# 1590 2021-05-10            326833.3     258.500000      5.750000
# 1591 2021-05-11                 NaN     298.500000      5.970000
#
#       T0-S0-INF-SRP  T0-S0-INF-BOD  T0-S0-INF-COD  T0-S0-INF-CBOD  \
# 0               NaN            NaN            NaN             NaN
# ...

# %%
# Write to PostgreSQL
start_time = time.time()
df.to_sql('Influent', con=conn, if_exists='replace', index=False)
print("to_sql duration: {} seconds".format(time.time() - start_time))
# Out:
# to_sql duration: 0.35741519927978516 seconds

# %%
# Close the connection
conn.close()
