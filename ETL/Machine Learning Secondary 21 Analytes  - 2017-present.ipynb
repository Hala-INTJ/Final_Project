# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display all columns
pd.options.display.max_columns = None

# Import ETL.py python file
import ETL

# %%
# Process Area: Secondary Treatment

# Read the excel file
excel_path = '../Raw Data/Machine Learning Secondary 21 Analytes  - 2017-present.xls'
df = pd.read_excel(excel_path)
df.head()
# Out:
#                Time                                        \
# 0                       ET.DC_SEC21_TSS_OPS_CALCULATED
# 1                                                first
# 2  2017-01-01 00:00:00                                NaN
# 3  2017-01-02 00:00:00                                NaN
# 4  2017-01-03 00:00:00                                4.8
#
#                    ET.DC_SEC21_TP_OPSLAB       ET.DC_SEC21_SRP_OPSLAB     \
# 0  Secondary 21 total phosphorus ops lab     Secondary 21 SRP ops lab
# 1                           first (mg/L)                 first (mg/L)
# 2                                       NaN                          NaN
# 3                                       NaN                          NaN
# 4                                       NaN                        0.263
#
#   WT.DC_SEC21_Chemical_Oxygen_Demand_-_COD_LR_3115BD     \
# 0                                             COD
# 1                                    first (mg/L)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   WT.DC_SEC21_Carbonaceous_Biochemical_Oxygen_Demand_-_CBOD_LDT_30A999     \
# 0   Carbonaceous Biochemical Oxygen Demand / CBOD
# 1                                    first (mg/L)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   WT.DC_SEC21_Total_Kjeldahl_Nitrogen_-_TKN_LDT_30A99A     \
# 0                   Total Kjeldahl Nitrogen / TKN
# 1                                    first (mg/L)
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993     \
# 0                        Ammonia (total, as N)
# 1                                 first (mg/L)
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
#
#   WT.DC_SEC21_Nitrate_[as_N]_LDT_30A995     \
# 0                        Nitrate (as N)
# 1                          first (mg/L)
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   WT.DC_SEC21_Nitrite_[as_N]_LDT_30A994
# 0                        Nitrite (as N)
# 1                          first (mg/L)
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN

# %%
# Add a header to column 1
df.rename(columns={df.columns[1]: df.iloc[0,1]}, inplace=True)

# dropping top 2 rows of the dataframe (description and unit)
df.drop([0,1], inplace=True)

# Resetting the index
df.reset_index(inplace=True, drop=True)

# Remove any spaces in the columns' names
df.rename(columns=lambda x: x.strip(), inplace=True)

#  Convert the time column to datetime format
df['Time'] = pd.to_datetime(df['Time'])

# Displaying the top five rows of the dataframe
df.head()
# Out:
#         Time ET.DC_SEC21_TSS_OPS_CALCULATED ET.DC_SEC21_TP_OPSLAB  \
# 0 2017-01-01                            NaN                   NaN
# 1 2017-01-02                            NaN                   NaN
# 2 2017-01-03                            4.8                   NaN
# 3 2017-01-04                            NaN                 0.371
# 4 2017-01-05                            8.4                   NaN
#
#   ET.DC_SEC21_SRP_OPSLAB WT.DC_SEC21_Chemical_Oxygen_Demand_-_COD_LR_3115BD  \
# 0                    NaN                                                NaN
# 1                    NaN                                                NaN
# 2                  0.263                                                NaN
# 3                  0.276                                                NaN
# 4                  0.194                                               41.1
#
#   WT.DC_SEC21_Carbonaceous_Biochemical_Oxygen_Demand_-_CBOD_LDT_30A999  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   WT.DC_SEC21_Total_Kjeldahl_Nitrogen_-_TKN_LDT_30A99A  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   WT.DC_SEC21_Nitrate_[as_N]_LDT_30A995 WT.DC_SEC21_Nitrite_[as_N]_LDT_30A994
# 0                                   NaN                                   NaN
# 1                                   NaN                                   NaN
# 2                                   NaN                                   NaN
# 3                                   NaN                                   NaN
# 4                                   NaN                                   NaN

# %%
# Print a concise summary df the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 10 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Time                                                                  1592 non-null   datetime64[ns]
#  1   ET.DC_SEC21_TSS_OPS_CALCULATED                                        501 non-null    object
#  2   ET.DC_SEC21_TP_OPSLAB                                                 464 non-null    object
#  3   ET.DC_SEC21_SRP_OPSLAB                                                1058 non-null   object
#  4   WT.DC_SEC21_Chemical_Oxygen_Demand_-_COD_LR_3115BD                    220 non-null    object
#  5   WT.DC_SEC21_Carbonaceous_Biochemical_Oxygen_Demand_-_CBOD_LDT_30A999  48 non-null     object
#  6   WT.DC_SEC21_Total_Kjeldahl_Nitrogen_-_TKN_LDT_30A99A                  48 non-null     object
#  7   WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993                          48 non-null     object
#  8   WT.DC_SEC21_Nitrate_[as_N]_LDT_30A995                                 48 non-null     object
#  9   WT.DC_SEC21_Nitrite_[as_N]_LDT_30A994                                 48 non-null     object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 124.5+ KB

# %%
# Create a Series for "Time" column
time_column = df["Time"]

# Return the columns as a list and drop "Time"
columns_list = df.columns.tolist()
columns_list.remove('Time')
columns_list
# Out:
# ['ET.DC_SEC21_TSS_OPS_CALCULATED',
#  'ET.DC_SEC21_TP_OPSLAB',
#  'ET.DC_SEC21_SRP_OPSLAB',
#  'WT.DC_SEC21_Chemical_Oxygen_Demand_-_COD_LR_3115BD',
#  'WT.DC_SEC21_Carbonaceous_Biochemical_Oxygen_Demand_-_CBOD_LDT_30A999',
#  'WT.DC_SEC21_Total_Kjeldahl_Nitrogen_-_TKN_LDT_30A99A',
#  'WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993',
#  'WT.DC_SEC21_Nitrate_[as_N]_LDT_30A995',
#  'WT.DC_SEC21_Nitrite_[as_N]_LDT_30A994']

# %%
# Check for "NT" or for "OS" values
((df == "NT") | (df == "OS")).any().sum()
# Out:
# 3

# %%
# Replace "NT" and "OS" values with with NaN
df = df.mask((df == "NT") | (df == "OS"))

# %%
# Check for "<x" and replace it with "x/2"
import re 

for col in columns_list:
    df[col] = df[col].astype(str)
    df[col] = df[col].apply(lambda x: float(x.lstrip('<'))/2 if bool(re.match(r'(^<.*)', x)) else x)  
    
df = df.mask(df == 'nan')

# %%
# Convert to numeric type
df = df[columns_list].apply(pd.to_numeric, errors='raise')
df.head()
# Out:
#    ET.DC_SEC21_TSS_OPS_CALCULATED  ET.DC_SEC21_TP_OPSLAB  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             4.8                    NaN
# 3                             NaN                  0.371
# 4                             8.4                    NaN
#
#    ET.DC_SEC21_SRP_OPSLAB  WT.DC_SEC21_Chemical_Oxygen_Demand_-_COD_LR_3115BD  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2                   0.263                                                NaN
# 3                   0.276                                                NaN
# 4                   0.194                                               41.1
#
#    WT.DC_SEC21_Carbonaceous_Biochemical_Oxygen_Demand_-_CBOD_LDT_30A999  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    WT.DC_SEC21_Total_Kjeldahl_Nitrogen_-_TKN_LDT_30A99A  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    WT.DC_SEC21_Nitrate_[as_N]_LDT_30A995  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    WT.DC_SEC21_Nitrite_[as_N]_LDT_30A994
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN

# %%
# Scatter plot for each column to inspect the data
df.plot(subplots=True, layout=(8, 2), figsize=(30, 50), marker='o')
plt.show()

# %%
# Inserting the 'Time' column
df.insert(0, "Time", time_column)

# Check for outliers
outliers_df = ETL.find_outliers_analytes(df,columns_list,time_column)
print(f"The total number of ouliers are {len(outliers_df)}")
outliers_df
# Out:
# The total number of ouliers are 2
#                                        tag_name  value  index      score
# 0                        ET.DC_SEC21_SRP_OPSLAB  28.70    304  33.575995
# 1  WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993   3.55    491  17.255347

# %%
# Clean outliers by assigning them to NaN
df = ETL.clean_outliers_analytes(df,columns_list,time_column)

# %%
# Drop the time column
df.drop('Time', inplace = True, axis = 1)
df.head()
# Out:
#    ET.DC_SEC21_TSS_OPS_CALCULATED  ET.DC_SEC21_TP_OPSLAB  \
# 0                             NaN                    NaN
# 1                             NaN                    NaN
# 2                             4.8                    NaN
# 3                             NaN                  0.371
# 4                             8.4                    NaN
#
#    ET.DC_SEC21_SRP_OPSLAB  WT.DC_SEC21_Chemical_Oxygen_Demand_-_COD_LR_3115BD  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2                   0.263                                                NaN
# 3                   0.276                                                NaN
# 4                   0.194                                               41.1
#
#    WT.DC_SEC21_Carbonaceous_Biochemical_Oxygen_Demand_-_CBOD_LDT_30A999  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    WT.DC_SEC21_Total_Kjeldahl_Nitrogen_-_TKN_LDT_30A99A  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    WT.DC_SEC21_Nitrate_[as_N]_LDT_30A995  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    WT.DC_SEC21_Nitrite_[as_N]_LDT_30A994
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN

# %%
# Checking for negative values
(df < 0).any().sum()
# Out:
# 1

# %%
# Replace negative values with 0
df = df.mask(df < 0, 0)

# %%
# Interplolation using 'pchip' (Piecewise Cubic Hermite Interpolating Polynomial)
df = df.interpolate(method='pchip',limit_area='inside')

# %%
# Checking for negative values
(df < 0).any().sum()
# Out:
# 0

# %%
# Scatter plot for each column after interpolation
df.plot(subplots=True, layout=(8, 2), figsize=(30, 50), marker='o')
plt.show()

# %%
# Inserting the 'Time' column
df.insert(0, "Time", time_column)
df.head()
# Out:
#         Time  ET.DC_SEC21_TSS_OPS_CALCULATED  ET.DC_SEC21_TP_OPSLAB  \
# 0 2017-01-01                             NaN                    NaN
# 1 2017-01-02                             NaN                    NaN
# 2 2017-01-03                            4.80                    NaN
# 3 2017-01-04                            7.19                0.37100
# 4 2017-01-05                            8.40                0.37137
#
#    ET.DC_SEC21_SRP_OPSLAB  WT.DC_SEC21_Chemical_Oxygen_Demand_-_COD_LR_3115BD  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2                   0.263                                                NaN
# 3                   0.276                                                NaN
# 4                   0.194                                               41.1
#
#    WT.DC_SEC21_Carbonaceous_Biochemical_Oxygen_Demand_-_CBOD_LDT_30A999  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    WT.DC_SEC21_Total_Kjeldahl_Nitrogen_-_TKN_LDT_30A99A  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    WT.DC_SEC21_Nitrate_[as_N]_LDT_30A995  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    WT.DC_SEC21_Nitrite_[as_N]_LDT_30A994
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN

# %%
# Print a concise summary df the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1592 entries, 0 to 1591
# Data columns (total 10 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Time                                                                  1592 non-null   datetime64[ns]
#  1   ET.DC_SEC21_TSS_OPS_CALCULATED                                        1590 non-null   float64
#  2   ET.DC_SEC21_TP_OPSLAB                                                 1589 non-null   float64
#  3   ET.DC_SEC21_SRP_OPSLAB                                                1590 non-null   float64
#  4   WT.DC_SEC21_Chemical_Oxygen_Demand_-_COD_LR_3115BD                    1587 non-null   float64
#  5   WT.DC_SEC21_Carbonaceous_Biochemical_Oxygen_Demand_-_CBOD_LDT_30A999  1540 non-null   float64
#  6   WT.DC_SEC21_Total_Kjeldahl_Nitrogen_-_TKN_LDT_30A99A                  1540 non-null   float64
#  7   WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993                          1540 non-null   float64
#  8   WT.DC_SEC21_Nitrate_[as_N]_LDT_30A995                                 1540 non-null   float64
#  9   WT.DC_SEC21_Nitrite_[as_N]_LDT_30A994                                 1540 non-null   float64
# dtypes: datetime64[ns](1), float64(9)
# memory usage: 124.5 KB

# %%
# Indices of the first and last non-NaN values
for col in columns_list:
    print(f"Data found from {df[col].notna().idxmax()} to {df[col].notna()[::-1].idxmax()} for {col}")
# Out:
# Data found from 2 to 1591 for ET.DC_SEC21_TSS_OPS_CALCULATED
# Data found from 3 to 1591 for ET.DC_SEC21_TP_OPSLAB
# Data found from 2 to 1591 for ET.DC_SEC21_SRP_OPSLAB
# Data found from 4 to 1590 for WT.DC_SEC21_Chemical_Oxygen_Demand_-_COD_LR_3115BD
# Data found from 16 to 1555 for WT.DC_SEC21_Carbonaceous_Biochemical_Oxygen_Demand_-_CBOD_LDT_30A999
# Data found from 16 to 1555 for WT.DC_SEC21_Total_Kjeldahl_Nitrogen_-_TKN_LDT_30A99A
# Data found from 16 to 1555 for WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993
# Data found from 16 to 1555 for WT.DC_SEC21_Nitrate_[as_N]_LDT_30A995
# Data found from 16 to 1555 for WT.DC_SEC21_Nitrite_[as_N]_LDT_30A994

# %%
# DataFrame resulting from the pre-processing
df.head()
# Out:
#         Time  ET.DC_SEC21_TSS_OPS_CALCULATED  ET.DC_SEC21_TP_OPSLAB  \
# 0 2017-01-01                             NaN                    NaN
# 1 2017-01-02                             NaN                    NaN
# 2 2017-01-03                            4.80                    NaN
# 3 2017-01-04                            7.19                0.37100
# 4 2017-01-05                            8.40                0.37137
#
#    ET.DC_SEC21_SRP_OPSLAB  WT.DC_SEC21_Chemical_Oxygen_Demand_-_COD_LR_3115BD  \
# 0                     NaN                                                NaN
# 1                     NaN                                                NaN
# 2                   0.263                                                NaN
# 3                   0.276                                                NaN
# 4                   0.194                                               41.1
#
#    WT.DC_SEC21_Carbonaceous_Biochemical_Oxygen_Demand_-_CBOD_LDT_30A999  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    WT.DC_SEC21_Total_Kjeldahl_Nitrogen_-_TKN_LDT_30A99A  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    WT.DC_SEC21_Ammonia_[total-_as_N]_LDT_30A993  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    WT.DC_SEC21_Nitrate_[as_N]_LDT_30A995  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#    WT.DC_SEC21_Nitrite_[as_N]_LDT_30A994
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN

# %%
# List of the new columns names
new_columns_names = ['Time',
"T5-S3-SEC-S21-TSS",
"T5-S3-SEC-S21-TP",
"T5-S3-SEC-S21-SRP",
"T5-S3-SEC-S21-COD",
"T5-S3-SEC-S21-CBOD",
"T5-S3-SEC-S21-TKN",
"T5-S3-SEC-S21-Ammonia",
"T5-S3-SEC-S21-Nitrate",
"T5-S3-SEC-S21-Nitrite"]

# %%
# Rename the columns
df.columns = new_columns_names
df
# Out:
#            Time  T5-S3-SEC-S21-TSS  T5-S3-SEC-S21-TP  T5-S3-SEC-S21-SRP  \
# 0    2017-01-01                NaN               NaN                NaN
# 1    2017-01-02                NaN               NaN                NaN
# 2    2017-01-03           4.800000               NaN           0.263000
# 3    2017-01-04           7.190000          0.371000           0.276000
# 4    2017-01-05           8.400000          0.371370           0.194000
# ...         ...                ...               ...                ...
# 1587 2021-05-07           7.511111          0.333111           0.108073
# 1588 2021-05-08           5.488889          0.273889           0.109481
# 1589 2021-05-09           4.400000          0.242000           0.110000
# 1590 2021-05-10           4.845000          0.243500           0.089000
# 1591 2021-05-11           6.200000          0.254000           0.092000
#
#       T5-S3-SEC-S21-COD  T5-S3-SEC-S21-CBOD  T5-S3-SEC-S21-TKN  \
# 0                   NaN                 NaN                NaN
# 1                   NaN                 NaN                NaN
# 2                   NaN                 NaN                NaN
# 3                   NaN                 NaN                NaN
# 4             41.100000                 NaN                NaN
# ...                 ...                 ...                ...
# 1587          37.535277                 NaN                NaN
# 1588          39.783090                 NaN                NaN
# 1589          42.774927                 NaN                NaN
# 1590          46.600000                 NaN                NaN
# 1591                NaN                 NaN                NaN
#
#       T5-S3-SEC-S21-Ammonia  T5-S3-SEC-S21-Nitrate  T5-S3-SEC-S21-Nitrite
# 0                       NaN                    NaN                    NaN
# 1                       NaN                    NaN                    NaN
# 2                       NaN                    NaN                    NaN
# 3                       NaN                    NaN                    NaN
# 4                       NaN                    NaN                    NaN
# ...                     ...                    ...                    ...
# 1587                    NaN                    NaN                    NaN
# 1588                    NaN                    NaN                    NaN
# 1589                    NaN                    NaN                    NaN
# 1590                    NaN                    NaN                    NaN
# 1591                    NaN                    NaN                    NaN
#
# [1592 rows x 10 columns]

# %%
# Connect to the PostgreSQL database server
from sqlalchemy import create_engine
import time

engine = create_engine("postgresql://postgres:postgres@localhost/WWTP")
conn = engine.connect()

# Write to PostgreSQL
start_time = time.time()
df.to_sql('secondary_temp_5', con=conn, if_exists='replace', index=False)
print("to_sql duration: {} seconds".format(time.time() - start_time))
# Out:
# to_sql duration: 0.3159642219543457 seconds

# %%
# Close the connection
conn.close()
