# %%
# Import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Display all columns
pd.options.display.max_columns = None

# %%
# Process Area: Aeration

# Read the excel File
excel_path = '../Raw Data/Tags.xls'
df = pd.read_excel(excel_path)
df.head()
# Out:
#       Table                 ML Tag Train Stage Process Area Pri/Sec      Type  \
# 0  Aeration  T1-S1-AER-P1-EFF-Flow     1     1          AER      P1  EFF-Flow
# 1  Aeration  T1-S1-AER-P2-EFF-Flow     1     1          AER      P2  EFF-Flow
# 2  Aeration  T2-S1-AER-P3-EFF-Flow     2     1          AER      P3  EFF-Flow
# 3  Aeration  T2-S1-AER-P4-EFF-Flow     2     1          AER      P4  EFF-Flow
# 4  Aeration  T3-S2-AER-P5-EFF-Flow     3     2          AER      P5  EFF-Flow
#
#                                  Source File  \
# 0  Aeration Air, DO Flows MLSS Stage 1 and 2
# 1  Aeration Air, DO Flows MLSS Stage 1 and 2
# 2  Aeration Air, DO Flows MLSS Stage 1 and 2
# 3  Aeration Air, DO Flows MLSS Stage 1 and 2
# 4  Aeration Air, DO Flows MLSS Stage 1 and 2
#
#                                  Tag                   Description  \
# 0  PH.DCPN3.DC_AER_FIT_0101_FIV.F_CV  MCP1 BAS1 Volume Flow (F_CV)
# 1  PH.DCPN3.DC_AER_FIT_0201_FIV.F_CV  MCP1 BAS2 Volume Flow (F_CV)
# 2  PH.DCPN3.DC_AER_FIT_0301_FIV.F_CV  MCP1 BAS3 Volume Flow (F_CV)
# 3  PH.DCPN3.DC_AER_FIT_0401_FIV.F_CV  MCP1 BAS4 Volume Flow (F_CV)
# 4  PH.DCPN3.DC_AER_FIT_0501_FIV.F_CV  MCP2 BAS5 Volume Flow (F_CV)
#
#              Units
# 0  average (m3/hr)
# 1  average (m3/hr)
# 2  average (m3/hr)
# 3  average (m3/hr)
# 4  average (m3/hr)

# %%
df.columns
# Out:
# Index(['Table', 'ML Tag', 'Train', 'Stage', 'Process Area', 'Pri/Sec', 'Type',
#        'Source File', 'Tag', 'Description', 'Units'],
#       dtype='object')

# %%
# Remove any spaces in the columns' names
df.rename(columns=lambda x: x.strip(), inplace=True)

# Re-arrange the columns
df = df[['ML Tag','Train', 'Stage', 'Process Area', 'Pri/Sec', 'Type',
         'Table','Source File', 'Tag', 'Description', 'Units']]

# Displaying the top five rows of the dataframe
df.head()
# Out:
#                   ML Tag Train Stage Process Area Pri/Sec      Type     Table  \
# 0  T1-S1-AER-P1-EFF-Flow     1     1          AER      P1  EFF-Flow  Aeration
# 1  T1-S1-AER-P2-EFF-Flow     1     1          AER      P2  EFF-Flow  Aeration
# 2  T2-S1-AER-P3-EFF-Flow     2     1          AER      P3  EFF-Flow  Aeration
# 3  T2-S1-AER-P4-EFF-Flow     2     1          AER      P4  EFF-Flow  Aeration
# 4  T3-S2-AER-P5-EFF-Flow     3     2          AER      P5  EFF-Flow  Aeration
#
#                                  Source File  \
# 0  Aeration Air, DO Flows MLSS Stage 1 and 2
# 1  Aeration Air, DO Flows MLSS Stage 1 and 2
# 2  Aeration Air, DO Flows MLSS Stage 1 and 2
# 3  Aeration Air, DO Flows MLSS Stage 1 and 2
# 4  Aeration Air, DO Flows MLSS Stage 1 and 2
#
#                                  Tag                   Description  \
# 0  PH.DCPN3.DC_AER_FIT_0101_FIV.F_CV  MCP1 BAS1 Volume Flow (F_CV)
# 1  PH.DCPN3.DC_AER_FIT_0201_FIV.F_CV  MCP1 BAS2 Volume Flow (F_CV)
# 2  PH.DCPN3.DC_AER_FIT_0301_FIV.F_CV  MCP1 BAS3 Volume Flow (F_CV)
# 3  PH.DCPN3.DC_AER_FIT_0401_FIV.F_CV  MCP1 BAS4 Volume Flow (F_CV)
# 4  PH.DCPN3.DC_AER_FIT_0501_FIV.F_CV  MCP2 BAS5 Volume Flow (F_CV)
#
#              Units
# 0  average (m3/hr)
# 1  average (m3/hr)
# 2  average (m3/hr)
# 3  average (m3/hr)
# 4  average (m3/hr)

# %%
# Print a concise summary df the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ML Tag        290 non-null    object
#  1   Train         290 non-null    object
#  2   Stage         290 non-null    object
#  3   Process Area  290 non-null    object
#  4   Pri/Sec       257 non-null    object
#  5   Type          290 non-null    object
#  6   Table         290 non-null    object
#  7   Source File   290 non-null    object
#  8   Tag           290 non-null    object
#  9   Description   274 non-null    object
#  10  Units         290 non-null    object
# dtypes: object(11)
# memory usage: 25.0+ KB

# %%
# Connect to the PostgreSQL database server
from sqlalchemy import create_engine
import time

engine = create_engine("postgresql://postgres:postgres@localhost/WWTP")
conn = engine.connect()

# Write to PostgreSQL
start_time = time.time()
df.to_sql('Tags', con=conn, if_exists='replace', index=False)
print("to_sql duration: {} seconds".format(time.time() - start_time))
# Out:
# to_sql duration: 0.04299592971801758 seconds

# %%
# Close the connection
conn.close()
