# %%
# Import dependencies
import pandas as pd
import datetime
import re  
 
from sqlalchemy import create_engine

# Display all columns
pd.options.display.max_columns = None

# Supress warnings
import warnings
warnings.filterwarnings("ignore")

# Import Classification_Models.py python file
import Classification_Models

# %%
# Train: 12

# Connecting to the Database
engine = create_engine("postgresql://postgres:postgres@localhost/WWTP")
conn = engine.connect()

# Reading SQL query into a Dataframe 
df_1 = pd.read_sql_query('select * from "Preliminary"', con=conn)
df_2 = pd.read_sql_query('select * from "Primary"', con=conn)
df_3 = pd.read_sql_query('select * from "Aeration"', con=conn)
df_4 = pd.read_sql_query('select * from "Secondary"', con=conn)

# Close the connection
conn.close()

# %%
# Selecting specific columns
df_1 = df_1[['Time','T6-S3-PRE-FeCL2']]

# %%
# Selecting specific columns using Regex
specific_columns = []
for col in list(df_2.columns):
    if (re.match(r'(^T6.*-P12-.*|Time)', col)):
        specific_columns.append(col) 
        
df_2 = df_2[specific_columns]

# %%
# Selecting specific columns using Regex
specific_columns = []
for col in list(df_3.columns):
    if (re.match(r'(^T6.*-P12.*|Time)', col)): 
        specific_columns.append(col)
        
df_3 = df_3[specific_columns]

# %%
# Selecting specific columns using Regex
specific_columns = []
for col in list(df_4.columns):
    if (re.match(r'(^T[5,6].*-S20.*|Time)', col)):
        specific_columns.append(col)
        
df_4 = df_4[specific_columns]

# %%
# Merging Dataframes
df_temp_1 = pd.merge(df_1, df_2, on='Time', how='outer')
df_temp_2 = pd.merge(df_temp_1, df_3, on='Time', how='outer')
df = pd.merge(df_temp_2, df_4, on='Time', how='outer')
df.head()
# Out:
#         Time  T6-S3-PRE-FeCL2  T6-S3-PRI-P12-RSD  T6-S3-PRI-P12-TSS  \
# 0 2017-01-01              0.0                NaN                NaN
# 1 2017-01-02              0.0                7.0                NaN
# 2 2017-01-03              0.0                7.5         199.000000
# 3 2017-01-04              0.0                6.5         155.210714
# 4 2017-01-05              0.0                6.5         134.000000
#
#    T6-S3-PRI-P12-TP  T6-S3-PRI-P12-SRP  T6-S3-PRI-P12-COD  T6-S3-PRI-P12-TKN  \
# 0               NaN                NaN                NaN                NaN
# 1               NaN                NaN                NaN                NaN
# 2               NaN                NaN         350.000000                NaN
# 3          8.440000           5.670000         344.928780                NaN
# 4          7.527564           4.999679         340.007497                NaN
#
#    T6-S3-PRI-P12-Ammonia  T6-S3-PRI-P12-Nitrate  T6-S3-PRI-P12-Nitrite  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    T6-S3-PRI-P12-RSS  T6-S3-AER-P12.1-DO  T6-S3-AER-P12.2-DO  \
# 0                NaN            0.111275            0.826188
# 1                NaN            0.111741            0.827080
# 2           2.700000            0.111891            0.826187
# 3           2.621071            0.113194            0.821945
# 4           2.600000            0.112556            0.862405
#
#    T6-S3-AER-P12.3-DO  T6-S3-AER-P12.4-DO  T6-S3-AER-P12-MLSS  \
# 0            2.981943            1.864936         3549.452674
# 1            2.818660            1.847113         3350.283118
# 2            1.939339            1.659372         3333.231389
# 3            1.645539            1.838842         3602.924649
# 4            3.213642            1.893825         3357.787685
#
#    T6-S3-SEC-S20-EFF-Flow  T6-S3-SEC-S20-RSD  T6-S3-SEC-S20-WAS-Flow  \
# 0                33049.25                NaN                962.0296
# 1                32604.20                NaN                916.5244
# 2                45201.38                1.0                718.0848
# 3                49309.60                0.0                715.4219
# 4                38294.87                0.0                720.2491
#
#    T5-S3-SEC-S20-TSS  T5-S3-SEC-S20-TP  T5-S3-SEC-S20-SRP  T5-S3-SEC-S20-COD  \
# 0                NaN               NaN                NaN                NaN
# 1                NaN               NaN                NaN                NaN
# 2           7.200000               NaN              0.252                NaN
# 3           5.926454          0.329000              0.253                NaN
# 4           5.200000          0.328978              0.180               35.2
#
#    T5-S3-SEC-S20-CBOD  T5-S3-SEC-S20-TKN  T5-S3-SEC-S20-Ammonia  \
# 0                 NaN                NaN                    NaN
# 1                 NaN                NaN                    NaN
# 2                 NaN                NaN                    NaN
# 3                 NaN                NaN                    NaN
# 4                 NaN                NaN                    NaN
#
#    T5-S3-SEC-S20-Nitrate  T5-S3-SEC-S20-Nitrite
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2                    NaN                    NaN
# 3                    NaN                    NaN
# 4                    NaN                    NaN

# %%
# Add a classified column for 'TP' - value of 0 for exceedance "out of compliance"
df['TP_Exceedance'] = df['T5-S3-SEC-S20-TP'].apply(lambda x: 1 if x < 0.35 else 0)
df.drop('T5-S3-SEC-S20-TP', inplace = True, axis = 1)

# Keeping the records satring on July 1st, 2017
df = df[df['Time'] >= datetime.datetime(2017,7,1)].sort_values(by='Time')

# Resetting the index
df.reset_index(inplace=True, drop=True)

print(df.shape)
df.head()
# Out:
# (1411, 29)
#         Time  T6-S3-PRE-FeCL2  T6-S3-PRI-P12-RSD  T6-S3-PRI-P12-TSS  \
# 0 2017-07-01          2.00000          10.000000         189.538764
# 1 2017-07-02          2.00000           9.500000         185.352921
# 2 2017-07-03          2.00000           8.603261         184.000000
# 3 2017-07-04          2.00000           8.000000         185.000000
# 4 2017-07-05          2.60463           8.000000         186.000000
#
#    T6-S3-PRI-P12-TP  T6-S3-PRI-P12-SRP  T6-S3-PRI-P12-COD  T6-S3-PRI-P12-TKN  \
# 0          4.683228           2.745854         366.089238                NaN
# 1          4.690582           2.742640         329.961465                NaN
# 2          4.699513           2.740669         316.000000                NaN
# 3          4.710000           2.740000         316.110787                NaN
# 4          4.864510           2.783761         316.396501                NaN
#
#    T6-S3-PRI-P12-Ammonia  T6-S3-PRI-P12-Nitrate  T6-S3-PRI-P12-Nitrite  \
# 0                    NaN                    NaN                    NaN
# 1                    NaN                    NaN                    NaN
# 2                    NaN                    NaN                    NaN
# 3                    NaN                    NaN                    NaN
# 4                    NaN                    NaN                    NaN
#
#    T6-S3-PRI-P12-RSS  T6-S3-AER-P12.1-DO  T6-S3-AER-P12.2-DO  \
# 0           3.145655            0.109228            0.822614
# 1           3.109625            0.111140            0.816271
# 2           3.069063            0.112173            0.771100
# 3           3.000000            0.111105            0.799839
# 4           2.827174            0.108131            0.747790
#
#    T6-S3-AER-P12.3-DO  T6-S3-AER-P12.4-DO  T6-S3-AER-P12-MLSS  \
# 0            2.057882            1.839172         3360.277671
# 1            2.668580            1.683184         3133.208846
# 2            2.034224            1.848552         2760.989590
# 3            1.390443            1.894292         2619.413324
# 4            1.407919            1.795763         2783.745769
#
#    T6-S3-SEC-S20-EFF-Flow  T6-S3-SEC-S20-RSD  T6-S3-SEC-S20-WAS-Flow  \
# 0                37435.50           1.421875                1436.433
# 1                34706.61           1.250000                1435.264
# 2                36200.45           1.078125                1423.857
# 3                36411.53           1.000000                1016.998
# 4                36554.44           1.000000                 363.987
#
#    T5-S3-SEC-S20-TSS  T5-S3-SEC-S20-SRP  T5-S3-SEC-S20-COD  \
# 0             8.9328           0.281364          34.676999
# 1             9.8256           0.293347          36.023753
# 2            10.2000           0.309000          37.399233
# 3             7.6000           0.347000          38.644346
# 4             5.0000           0.375000          39.600000
#
#    T5-S3-SEC-S20-CBOD  T5-S3-SEC-S20-TKN  T5-S3-SEC-S20-Ammonia  \
# 0            2.285997           1.418234               0.127823
# 1            2.362974           1.440875               0.130087
# 2            2.434375           1.461875               0.132188
# 3            2.499271           1.480962               0.134096
# 4            2.556733           1.497863               0.135786
#
#    T5-S3-SEC-S20-Nitrate  T5-S3-SEC-S20-Nitrite  TP_Exceedance
# 0              19.917789               0.061451              0
# 1              19.944925               0.062854              0
# 2              19.972586               0.064156              0
# 3              20.001000               0.065340              0
# 4              20.030393               0.066387              0

# %%
# Indices of the first and last non-NaN values
for col in list(df.columns):
    print(f"Data found from {df[col].notna().idxmax()} to {df[col].notna()[::-1].idxmax()} for {col}")
# Out:
# Data found from 0 to 1410 for Time
# Data found from 0 to 1410 for T6-S3-PRE-FeCL2
# Data found from 0 to 1409 for T6-S3-PRI-P12-RSD
# Data found from 0 to 1410 for T6-S3-PRI-P12-TSS
# Data found from 0 to 1410 for T6-S3-PRI-P12-TP
# Data found from 0 to 1409 for T6-S3-PRI-P12-SRP
# Data found from 0 to 1409 for T6-S3-PRI-P12-COD
# Data found from 478 to 1374 for T6-S3-PRI-P12-TKN
# Data found from 478 to 1374 for T6-S3-PRI-P12-Ammonia
# Data found from 478 to 1374 for T6-S3-PRI-P12-Nitrate
# Data found from 478 to 1374 for T6-S3-PRI-P12-Nitrite
# Data found from 0 to 1405 for T6-S3-PRI-P12-RSS
# Data found from 0 to 1410 for T6-S3-AER-P12.1-DO
# Data found from 0 to 1410 for T6-S3-AER-P12.2-DO
# Data found from 0 to 1410 for T6-S3-AER-P12.3-DO
# Data found from 0 to 1410 for T6-S3-AER-P12.4-DO
# Data found from 0 to 1410 for T6-S3-AER-P12-MLSS
# Data found from 0 to 1409 for T6-S3-SEC-S20-EFF-Flow
# Data found from 0 to 1409 for T6-S3-SEC-S20-RSD
# Data found from 0 to 1409 for T6-S3-SEC-S20-WAS-Flow
# Data found from 0 to 1410 for T5-S3-SEC-S20-TSS
# Data found from 0 to 1410 for T5-S3-SEC-S20-SRP
# Data found from 0 to 1409 for T5-S3-SEC-S20-COD
# Data found from 0 to 1374 for T5-S3-SEC-S20-CBOD
# Data found from 0 to 1374 for T5-S3-SEC-S20-TKN
# Data found from 0 to 1374 for T5-S3-SEC-S20-Ammonia
# Data found from 0 to 1374 for T5-S3-SEC-S20-Nitrate
# Data found from 0 to 1374 for T5-S3-SEC-S20-Nitrite
# Data found from 0 to 1410 for TP_Exceedance

# %%
# Dropping columns due to missing data until November 2018
df = df.drop(columns=['T6-S3-PRI-P12-TKN','T6-S3-PRI-P12-Ammonia','T6-S3-PRI-P12-Nitrate','T6-S3-PRI-P12-Nitrite',
]) 
    
# Dropping NaN
df = df.dropna()

print(df.shape)
df
# Out:
# (1375, 25)
#            Time  T6-S3-PRE-FeCL2  T6-S3-PRI-P12-RSD  T6-S3-PRI-P12-TSS  \
# 0    2017-07-01          2.00000          10.000000         189.538764
# 1    2017-07-02          2.00000           9.500000         185.352921
# 2    2017-07-03          2.00000           8.603261         184.000000
# 3    2017-07-04          2.00000           8.000000         185.000000
# 4    2017-07-05          2.60463           8.000000         186.000000
# ...         ...              ...                ...                ...
# 1370 2021-04-01          6.50000           2.000000          91.726198
# 1371 2021-04-02          6.50000           2.000000          95.956137
# 1372 2021-04-03          6.50000           3.000000         101.383692
# 1373 2021-04-04          6.50000           4.000000         107.723659
# 1374 2021-04-05          6.50000           1.500000         114.690831
#
#       T6-S3-PRI-P12-TP  T6-S3-PRI-P12-SRP  T6-S3-PRI-P12-COD  \
# 0             4.683228           2.745854         366.089238
# 1             4.690582           2.742640         329.961465
# 2             4.699513           2.740669         316.000000
# 3             4.710000           2.740000         316.110787
# 4             4.864510           2.783761         316.396501
# ...                ...                ...                ...
# 1370          2.026086           0.006569         266.037901
# 1371          2.047772           0.008276         297.962099
# 1372          2.079954           0.011126         327.262391
# 1373          2.123686           0.015120         348.690962
# 1374          2.180017           0.020262         357.000000
#
#       T6-S3-PRI-P12-RSS  T6-S3-AER-P12.1-DO  T6-S3-AER-P12.2-DO  \
# 0              3.145655            0.109228            0.822614
# 1              3.109625            0.111140            0.816271
# 2              3.069063            0.112173            0.771100
# 3              3.000000            0.111105            0.799839
# 4              2.827174            0.108131            0.747790
# ...                 ...                 ...                 ...
# 1370           3.325291            0.124000            0.928496
# 1371           3.252568            0.122660            0.861057
# 1372           3.173332            0.121143            0.782570
# 1373           3.100609            0.120287            0.738084
# 1374           3.047423            0.120870            0.713292
#
#       T6-S3-AER-P12.3-DO  T6-S3-AER-P12.4-DO  T6-S3-AER-P12-MLSS  \
# 0               2.057882            1.839172         3360.277671
# 1               2.668580            1.683184         3133.208846
# 2               2.034224            1.848552         2760.989590
# 3               1.390443            1.894292         2619.413324
# 4               1.407919            1.795763         2783.745769
# ...                  ...                 ...                 ...
# 1370            1.201528            2.631917         2802.147612
# 1371            1.552186            3.054535         2759.550261
# 1372            1.181926            2.761374         2784.063507
# 1373            1.183659            2.584082         2803.903387
# 1374            1.182122            2.375451         2821.892155
#
#       T6-S3-SEC-S20-EFF-Flow  T6-S3-SEC-S20-RSD  T6-S3-SEC-S20-WAS-Flow  \
# 0                   37435.50           1.421875               1436.4330
# 1                   34706.61           1.250000               1435.2640
# 2                   36200.45           1.078125               1423.8570
# 3                   36411.53           1.000000               1016.9980
# 4                   36554.44           1.000000                363.9870
# ...                      ...                ...                     ...
# 1370                32495.14           2.048573                520.0429
# 1371                32120.73           2.105799                513.9151
# 1372                32158.54           2.181881                504.6378
# 1373                31017.42           2.274494                514.9088
# 1374                31443.74           2.381309                513.6964
#
#       T5-S3-SEC-S20-TSS  T5-S3-SEC-S20-SRP  T5-S3-SEC-S20-COD  \
# 0              8.932800           0.281364          34.676999
# 1              9.825600           0.293347          36.023753
# 2             10.200000           0.309000          37.399233
# 3              7.600000           0.347000          38.644346
# 4              5.000000           0.375000          39.600000
# ...                 ...                ...                ...
# 1370           5.282799           0.056786          54.329186
# 1371           4.970262           0.056198          52.182451
# 1372           4.629738           0.055317          50.082145
# 1373           4.317201           0.054224          48.323063
# 1374           4.088630           0.053000          47.200000
#
#       T5-S3-SEC-S20-CBOD  T5-S3-SEC-S20-TKN  T5-S3-SEC-S20-Ammonia  \
# 0               2.285997           1.418234               0.127823
# 1               2.362974           1.440875               0.130087
# 2               2.434375           1.461875               0.132188
# 3               2.499271           1.480962               0.134096
# 4               2.556733           1.497863               0.135786
# ...                  ...                ...                    ...
# 1370            1.000000           1.451045               0.304878
# 1371            1.000000           1.450588               0.302761
# 1372            1.000000           1.450261               0.301235
# 1373            1.000000           1.450065               0.300311
# 1374            1.000000           1.450000               0.300000
#
#       T5-S3-SEC-S20-Nitrate  T5-S3-SEC-S20-Nitrite  TP_Exceedance
# 0                 19.917789               0.061451              0
# 1                 19.944925               0.062854              0
# 2                 19.972586               0.064156              0
# 3                 20.001000               0.065340              0
# 4                 20.030393               0.066387              0
# ...                     ...                    ...            ...
# 1370              20.951923               0.144952              1
# 1371              21.153203               0.139060              1
# 1372              21.361613               0.133100              1
# 1373              21.577197               0.127079              1
# 1374              21.800000               0.121000              1
#
# [1375 rows x 25 columns]

# %%
# Covert Time into numerical columns
df['month'] = df['Time'].dt.month
df['week'] = df['Time'].dt.week
df['day'] = df['Time'].dt.day

# %%
# Create a Series for "Time" column
time_column = df["Time"]

# Drop the time column
df.drop('Time', inplace = True, axis = 1)

# %%
df['TP_Exceedance'].value_counts()
# Out:
# 1    1198
# 0     177
# Name: TP_Exceedance, dtype: int64

# %%
# Segment the features from the target
y = df['TP_Exceedance']
X = df.drop(columns="TP_Exceedance")

# %%
# Running and evaluating models
Classification_Models.run_models(X, y)
# Out:
# Logistic Regression (lbfgs)
# Confusion matrix:
#  [[  0   3]
#  [ 13 397]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      0.97      0.98       410
#
#     accuracy                           0.96       413
#    macro avg       0.50      0.48      0.49       413
# weighted avg       0.99      0.96      0.97       413
#
#
#
# ----------------------------------------------
# SVC (poly)
#
# Confusion matrix:
#  [[  0   3]
#  [  8 402]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      0.98      0.99       410
#
#     accuracy                           0.97       413
#    macro avg       0.50      0.49      0.49       413
# weighted avg       0.99      0.97      0.98       413
#
#
#
# ----------------------------------------------
# Descision Tree Classification
# Confusion matrix:
#  [[  0   3]
#  [ 63 347]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      0.85      0.91       410
#
#     accuracy                           0.84       413
#    macro avg       0.50      0.42      0.46       413
# weighted avg       0.98      0.84      0.91       413
#
#
#
# ----------------------------------------------
# Random Forest Classification
# Confusion matrix:
#  [[  0   3]
#  [  2 408]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      1.00      0.99       410
#
#     accuracy                           0.99       413
#    macro avg       0.50      0.50      0.50       413
# weighted avg       0.99      0.99      0.99       413
#
#
#
# ----------------------------------------------
# Balanced Random Forest Classification
# Confusion matrix:
#  [[  1   2]
#  [ 14 396]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.07      0.33      0.11         3
#            1       0.99      0.97      0.98       410
#
#     accuracy                           0.96       413
#    macro avg       0.53      0.65      0.55       413
# weighted avg       0.99      0.96      0.97       413
#
#
#
# ----------------------------------------------
# Easy Ensemble Classification
#
# Confusion matrix:
#  [[  2   1]
#  [ 28 382]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.07      0.67      0.12         3
#            1       1.00      0.93      0.96       410
#
#     accuracy                           0.93       413
#    macro avg       0.53      0.80      0.54       413
# weighted avg       0.99      0.93      0.96       413
#
#
#
# ----------------------------------------------
# Gradient Boosting Classifier
#
# Confusion matrix:
#  [[  0   3]
#  [  9 401]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      0.98      0.99       410
#
#     accuracy                           0.97       413
#    macro avg       0.50      0.49      0.49       413
# weighted avg       0.99      0.97      0.98       413
#
#
#
# ----------------------------------------------
# AdaBoostClassifier
#
# Confusion matrix:
#  [[  1   2]
#  [  9 401]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.10      0.33      0.15         3
#            1       1.00      0.98      0.99       410
#
#     accuracy                           0.97       413
#    macro avg       0.55      0.66      0.57       413
# weighted avg       0.99      0.97      0.98       413
#
#
#
# ----------------------------------------------
#                                     Name Accuracy Score  \
# 0            Logistic Regression (lbfgs)         0.9613
# 1                             SVC (poly)         0.9734
# 2          Descision Tree Classification         0.8402
# 3           Random Forest Classification         0.9879
# 4  Balanced Random Forest Classification         0.9613
# 5           Easy Ensemble Classification         0.9298
# 6           Gradient Boosting Classifier         0.9709
# 7                     AdaBoostClassifier         0.9734
#
#   Balanced Accuracy Score  "Exceedance" Predicted Correctly (TP)  \
# 0                  0.4841                                      0
# 1                  0.4902                                      0
# 2                  0.4232                                      0
# 3                  0.4976                                      0
# 4                  0.6496                                      1
# 5                  0.7992                                      2
# 6                  0.4890                                      0
# 7                  0.6557                                      1
#
#    "Exceedance" Predicted Incorrectly (FP)  \
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        3
# 4                                        2
# 5                                        1
# 6                                        3
# 7                                        2
#
#    "No Exceedance" Predicted Incorrectly (FN)  \
# 0                                          13
# 1                                           8
# 2                                          63
# 3                                           2
# 4                                          14
# 5                                          28
# 6                                           9
# 7                                           9
#
#    "No Exceedance" Predicted Correctly (TN) Actual
# 0                                       397      3
# 1                                       402      3
# 2                                       347      3
# 3                                       408      3
# 4                                       396      3
# 5                                       382      3
# 6                                       401      3
# 7                                       401      3

# %%
# Running and evaluating models with SMOTEENN
Classification_Models.run_models(X, y, True)
# Out:
# Logistic Regression (lbfgs)
# Confusion matrix:
#  [[  0   3]
#  [ 49 361]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      0.88      0.93       410
#
#     accuracy                           0.87       413
#    macro avg       0.50      0.44      0.47       413
# weighted avg       0.98      0.87      0.93       413
#
#
#
# ----------------------------------------------
# SVC (poly)
#
# Confusion matrix:
#  [[  0   3]
#  [127 283]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      0.69      0.81       410
#
#     accuracy                           0.69       413
#    macro avg       0.49      0.35      0.41       413
# weighted avg       0.98      0.69      0.81       413
#
#
#
# ----------------------------------------------
# Descision Tree Classification
# Confusion matrix:
#  [[  0   3]
#  [ 89 321]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      0.78      0.87       410
#
#     accuracy                           0.78       413
#    macro avg       0.50      0.39      0.44       413
# weighted avg       0.98      0.78      0.87       413
#
#
#
# ----------------------------------------------
# Random Forest Classification
# Confusion matrix:
#  [[  2   1]
#  [ 19 391]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.10      0.67      0.17         3
#            1       1.00      0.95      0.98       410
#
#     accuracy                           0.95       413
#    macro avg       0.55      0.81      0.57       413
# weighted avg       0.99      0.95      0.97       413
#
#
#
# ----------------------------------------------
# Balanced Random Forest Classification
# Confusion matrix:
#  [[  2   1]
#  [ 13 397]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.13      0.67      0.22         3
#            1       1.00      0.97      0.98       410
#
#     accuracy                           0.97       413
#    macro avg       0.57      0.82      0.60       413
# weighted avg       0.99      0.97      0.98       413
#
#
#
# ----------------------------------------------
# Easy Ensemble Classification
#
# Confusion matrix:
#  [[  0   3]
#  [ 13 397]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         3
#            1       0.99      0.97      0.98       410
#
#     accuracy                           0.96       413
#    macro avg       0.50      0.48      0.49       413
# weighted avg       0.99      0.96      0.97       413
#
#
#
# ----------------------------------------------
# Gradient Boosting Classifier
#
# Confusion matrix:
#  [[  1   2]
#  [ 29 381]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.03      0.33      0.06         3
#            1       0.99      0.93      0.96       410
#
#     accuracy                           0.92       413
#    macro avg       0.51      0.63      0.51       413
# weighted avg       0.99      0.92      0.95       413
#
#
#
# ----------------------------------------------
# AdaBoostClassifier
#
# Confusion matrix:
#  [[  2   1]
#  [ 27 383]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.07      0.67      0.12         3
#            1       1.00      0.93      0.96       410
#
#     accuracy                           0.93       413
#    macro avg       0.53      0.80      0.54       413
# weighted avg       0.99      0.93      0.96       413
#
#
#
# ----------------------------------------------
#                                                Name Accuracy Score  \
# 0            Logistic Regression (lbfgs) (SMOTEENN)         0.8741
# 1                             SVC (poly) (SMOTEENN)         0.6852
# 2          Descision Tree Classification (SMOTEENN)         0.7772
# 3           Random Forest Classification (SMOTEENN)         0.9516
# 4  Balanced Random Forest Classification (SMOTEENN)         0.9661
# 5           Easy Ensemble Classification (SMOTEENN)         0.9613
# 6           Gradient Boosting Classifier (SMOTEENN)         0.9249
# 7                     AdaBoostClassifier (SMOTEENN)         0.9322
#
#   Balanced Accuracy Score  "Exceedance" Predicted Correctly (TP)  \
# 0                  0.4402                                      0
# 1                  0.3451                                      0
# 2                  0.3915                                      0
# 3                  0.8102                                      2
# 4                  0.8175                                      2
# 5                  0.4841                                      0
# 6                  0.6313                                      1
# 7                  0.8004                                      2
#
#    "Exceedance" Predicted Incorrectly (FP)  \
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        1
# 4                                        1
# 5                                        3
# 6                                        2
# 7                                        1
#
#    "No Exceedance" Predicted Incorrectly (FN)  \
# 0                                          49
# 1                                         127
# 2                                          89
# 3                                          19
# 4                                          13
# 5                                          13
# 6                                          29
# 7                                          27
#
#    "No Exceedance" Predicted Correctly (TN) Actual
# 0                                       361      3
# 1                                       283      3
# 2                                       321      3
# 3                                       391      3
# 4                                       397      3
# 5                                       397      3
# 6                                       381      3
# 7                                       383      3

# %%
# Running and evaluating Neural Network model
Classification_Models.neural_model(X, y, [100,75], 'linear', 500)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               2700
# _________________________________________________________________
# dense_1 (Dense)              (None, 75)                7575
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 76
# =================================================================
# Total params: 10,351
# Trainable params: 10,351
# Non-trainable params: 0
# _________________________________________________________________
# None
# 13/13 [==============================] - 0s 620us/step - loss: 0.1451 - accuracy: 0.9492
#                                    Name Accuracy Score Model Loss Predicition  \
# 0  Neural Model: [100, 75], linear, 500         0.9492     0.1451           0
#
#   Actual
# 0      3
