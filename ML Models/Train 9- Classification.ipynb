# %%
# Import dependencies
import pandas as pd
import datetime
import re  
 
from sqlalchemy import create_engine

# Display all columns
pd.options.display.max_columns = None

# Supress warnings
import warnings
warnings.filterwarnings("ignore")

# Import Classification_Models.py python file
import Classification_Models

# %%
# Train: 9

# Connecting to the Database
engine = create_engine("postgresql://postgres:postgres@localhost/WWTP")
conn = engine.connect()

# Reading SQL query into a Dataframe 
df_1 = pd.read_sql_query('select * from "Preliminary"', con=conn)
df_2 = pd.read_sql_query('select * from "Primary"', con=conn)
df_3 = pd.read_sql_query('select * from "Aeration"', con=conn)
df_4 = pd.read_sql_query('select * from "Secondary"', con=conn)

# Close the connection
conn.close()

# %%
# Selecting specific columns
df_1 = df_1[['Time','T5-S3-PRE-FeCL2']]

# %%
# Selecting specific columns using Regex
specific_columns = []
for col in list(df_2.columns):
    if (re.match(r'(^T5.*-P9-.*|Time)', col)):
        specific_columns.append(col) 
        
df_2 = df_2[specific_columns]

# %%
# Selecting specific columns using Regex
specific_columns = []
for col in list(df_3.columns):
    if (re.match(r'(^T5.*-P9.*|Time)', col)): 
        specific_columns.append(col)
        
df_3 = df_3[specific_columns]

# %%
# Selecting specific columns using Regex
specific_columns = []
for col in list(df_4.columns):
    if (re.match(r'(^T5.*-S17.*|Time)', col)):
        specific_columns.append(col)
        
df_4 = df_4[specific_columns]

# %%
# Merging Dataframes
df_temp_1 = pd.merge(df_1, df_2, on='Time', how='outer')
df_temp_2 = pd.merge(df_temp_1, df_3, on='Time', how='outer')
df = pd.merge(df_temp_2, df_4, on='Time', how='outer')
df.head()
# Out:
#         Time  T5-S3-PRE-FeCL2  T5-S3-PRI-P9-RSD  T5-S3-PRI-P9-TSS  \
# 0 2017-01-01              0.0               NaN               NaN
# 1 2017-01-02              0.0               7.0               NaN
# 2 2017-01-03              0.0               9.0               NaN
# 3 2017-01-04              0.0               7.5               NaN
# 4 2017-01-05              0.0               6.5             205.0
#
#    T5-S3-PRI-P9-TP  T5-S3-PRI-P9-SRP  T5-S3-PRI-P9-COD  T5-S3-PRI-P9-TKN  \
# 0              NaN               NaN               NaN               NaN
# 1              NaN               NaN               NaN               NaN
# 2              NaN               NaN               NaN               NaN
# 3         8.190000          5.710000               NaN               NaN
# 4         7.240466          4.961487               NaN               NaN
#
#    T5-S3-PRI-P9-Ammonia  T5-S3-PRI-P9-Nitrate  T5-S3-PRI-P9-Nitrite  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    T5-S3-PRI-P9-RSS  T5-S3-AER-P9.1-DO  T5-S3-AER-P9.2-DO  T5-S3-AER-P9.3-DO  \
# 0               NaN           0.122801           0.838862           1.317448
# 1               NaN           0.122768           0.811354           1.301577
# 2          2.500000           0.122591           0.767129           1.303124
# 3          3.236786           0.124397           0.883708           1.302646
# 4          3.600000           0.125704           0.821645           1.579656
#
#    T5-S3-AER-P9.4-DO  T5-S3-AER-P9-MLSS  T5-S3-SEC-S17-EFF-Flow  \
# 0           1.841194        3976.643204                32544.52
# 1           1.718150        3500.306460                31766.04
# 2           1.373911        3331.143707                45135.30
# 3           1.661259        3589.039968                49964.52
# 4           1.851710        3618.163545                47048.39
#
#    T5-S3-SEC-S17-RSD  T5-S3-SEC-S17-WAS-Flow  T5-S3-SEC-S17-TSS  \
# 0                NaN               1133.4530                NaN
# 1                NaN               1143.6030                NaN
# 2                1.0                838.8451           4.800000
# 3                0.0                833.6214           6.543571
# 4                0.0                401.2297           7.400000
#
#    T5-S3-SEC-S17-TP  T5-S3-SEC-S17-SRP  T5-S3-SEC-S17-COD  T5-S3-SEC-S17-CBOD  \
# 0               NaN                NaN                NaN                 NaN
# 1               NaN                NaN                NaN                 NaN
# 2               NaN              0.551                NaN                 NaN
# 3          0.626000              0.528                NaN                 NaN
# 4          0.624355              0.303               38.1                 NaN
#
#    T5-S3-SEC-S17-TKN  T5-S3-SEC-S17-Ammonia  T5-S3-SEC-S17-Nitrate  \
# 0                NaN                    NaN                    NaN
# 1                NaN                    NaN                    NaN
# 2                NaN                    NaN                    NaN
# 3                NaN                    NaN                    NaN
# 4                NaN                    NaN                    NaN
#
#    T5-S3-SEC-S17-Nitrite
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
# Add a classified column for 'TP' - value of 0 for exceedance "out of compliance"
df['TP_Exceedance'] = df['T5-S3-SEC-S17-TP'].apply(lambda x: 1 if x < 0.35 else 0)
df.drop('T5-S3-SEC-S17-TP', inplace = True, axis = 1)

# Keeping the records satring on July 1st, 2017
df = df[df['Time'] >= datetime.datetime(2017,7,1)].sort_values(by='Time')

# Resetting the index
df.reset_index(inplace=True, drop=True)

print(df.shape)
df.head()
# Out:
# (1411, 29)
#         Time  T5-S3-PRE-FeCL2  T5-S3-PRI-P9-RSD  T5-S3-PRI-P9-TSS  \
# 0 2017-07-01          2.00000          6.000000            109.16
# 1 2017-07-02          2.00000          5.500000            120.32
# 2 2017-07-03          2.00000          5.163462            125.00
# 3 2017-07-04          2.00000          5.000000            114.00
# 4 2017-07-05          2.60463          6.500000            103.00
#
#    T5-S3-PRI-P9-TP  T5-S3-PRI-P9-SRP  T5-S3-PRI-P9-COD  T5-S3-PRI-P9-TKN  \
# 0         3.411574          2.008416        283.429300               NaN
# 1         3.946793          2.406751        287.750729               NaN
# 2         4.338222          2.700736        292.000000               NaN
# 3         4.490000          2.820000        297.357143               NaN
# 4         4.486831          2.827868        304.535714               NaN
#
#    T5-S3-PRI-P9-Ammonia  T5-S3-PRI-P9-Nitrate  T5-S3-PRI-P9-Nitrite  \
# 0                   NaN                   NaN                   NaN
# 1                   NaN                   NaN                   NaN
# 2                   NaN                   NaN                   NaN
# 3                   NaN                   NaN                   NaN
# 4                   NaN                   NaN                   NaN
#
#    T5-S3-PRI-P9-RSS  T5-S3-AER-P9.1-DO  T5-S3-AER-P9.2-DO  T5-S3-AER-P9.3-DO  \
# 0          3.510481           0.116945           0.987359           1.528697
# 1          3.169654           0.119088           0.979271           1.543032
# 2          2.905885           0.120779           0.967874           1.516184
# 3          2.800000           0.119089           0.992098           1.523796
# 4          3.250000           0.114701           0.981230           1.516317
#
#    T5-S3-AER-P9.4-DO  T5-S3-AER-P9-MLSS  T5-S3-SEC-S17-EFF-Flow  \
# 0           1.910033        2602.392372                35437.05
# 1           1.882842        2628.553003                31718.03
# 2           1.907442        2664.045318                33271.28
# 3           1.885284        2814.841079                32689.61
# 4           1.906949        2890.660281                31768.31
#
#    T5-S3-SEC-S17-RSD  T5-S3-SEC-S17-WAS-Flow  T5-S3-SEC-S17-TSS  \
# 0           1.078125               493.04920          10.055807
# 1           1.250000               372.05800           9.181162
# 2           1.421875                19.71519           8.200000
# 3           1.500000               135.55710           6.146734
# 4           1.240741               250.95830           4.600000
#
#    T5-S3-SEC-S17-SRP  T5-S3-SEC-S17-COD  T5-S3-SEC-S17-CBOD  \
# 0           0.367086          37.608629            2.388263
# 1           0.393472          36.943206            2.354130
# 2           0.429000          36.436248            2.320414
# 3           0.528000          36.113323            2.287161
# 4           0.671000          36.000000            2.254418
#
#    T5-S3-SEC-S17-TKN  T5-S3-SEC-S17-Ammonia  T5-S3-SEC-S17-Nitrate  \
# 0           1.326713               0.244130              16.453469
# 1           1.305525               0.221023              16.687816
# 2           1.286504               0.200338              16.918477
# 3           1.269720               0.182153              17.145094
# 4           1.255245               0.166548              17.367314
#
#    T5-S3-SEC-S17-Nitrite  TP_Exceedance
# 0               0.253491              0
# 1               0.227237              0
# 2               0.203490              0
# 3               0.182373              0
# 4               0.164015              0

# %%
# Indices of the first and last non-NaN values
for col in list(df.columns):
    print(f"Data found from {df[col].notna().idxmax()} to {df[col].notna()[::-1].idxmax()} for {col}")
# Out:
# Data found from 0 to 1410 for Time
# Data found from 0 to 1410 for T5-S3-PRE-FeCL2
# Data found from 0 to 1409 for T5-S3-PRI-P9-RSD
# Data found from 0 to 1410 for T5-S3-PRI-P9-TSS
# Data found from 0 to 1410 for T5-S3-PRI-P9-TP
# Data found from 0 to 1409 for T5-S3-PRI-P9-SRP
# Data found from 0 to 1409 for T5-S3-PRI-P9-COD
# Data found from 478 to 1374 for T5-S3-PRI-P9-TKN
# Data found from 478 to 1374 for T5-S3-PRI-P9-Ammonia
# Data found from 506 to 1374 for T5-S3-PRI-P9-Nitrate
# Data found from 478 to 1374 for T5-S3-PRI-P9-Nitrite
# Data found from 0 to 1405 for T5-S3-PRI-P9-RSS
# Data found from 0 to 1410 for T5-S3-AER-P9.1-DO
# Data found from 0 to 1410 for T5-S3-AER-P9.2-DO
# Data found from 0 to 1410 for T5-S3-AER-P9.3-DO
# Data found from 0 to 1410 for T5-S3-AER-P9.4-DO
# Data found from 0 to 1410 for T5-S3-AER-P9-MLSS
# Data found from 0 to 1409 for T5-S3-SEC-S17-EFF-Flow
# Data found from 0 to 1409 for T5-S3-SEC-S17-RSD
# Data found from 0 to 1409 for T5-S3-SEC-S17-WAS-Flow
# Data found from 0 to 1410 for T5-S3-SEC-S17-TSS
# Data found from 0 to 1410 for T5-S3-SEC-S17-SRP
# Data found from 0 to 1409 for T5-S3-SEC-S17-COD
# Data found from 0 to 1374 for T5-S3-SEC-S17-CBOD
# Data found from 0 to 1374 for T5-S3-SEC-S17-TKN
# Data found from 0 to 1374 for T5-S3-SEC-S17-Ammonia
# Data found from 0 to 1374 for T5-S3-SEC-S17-Nitrate
# Data found from 0 to 1374 for T5-S3-SEC-S17-Nitrite
# Data found from 0 to 1410 for TP_Exceedance

# %%
# Dropping columns due to missing data until November 2018
df = df.drop(columns=['T5-S3-PRI-P9-TKN','T5-S3-PRI-P9-Ammonia','T5-S3-PRI-P9-Nitrate','T5-S3-PRI-P9-Nitrite',
]) 
    
# Dropping NaN
df = df.dropna()

print(df.shape)
df
# Out:
# (1375, 25)
#            Time  T5-S3-PRE-FeCL2  T5-S3-PRI-P9-RSD  T5-S3-PRI-P9-TSS  \
# 0    2017-07-01          2.00000          6.000000        109.160000
# 1    2017-07-02          2.00000          5.500000        120.320000
# 2    2017-07-03          2.00000          5.163462        125.000000
# 3    2017-07-04          2.00000          5.000000        114.000000
# 4    2017-07-05          2.60463          6.500000        103.000000
# ...         ...              ...               ...               ...
# 1370 2021-04-01          6.50000          2.000000         78.295918
# 1371 2021-04-02          6.50000          2.000000         89.918367
# 1372 2021-04-03          6.50000          1.500000        102.581633
# 1373 2021-04-04          6.50000          2.500000        114.204082
# 1374 2021-04-05          6.50000          2.500000        122.704082
#
#       T5-S3-PRI-P9-TP  T5-S3-PRI-P9-SRP  T5-S3-PRI-P9-COD  T5-S3-PRI-P9-RSS  \
# 0            3.411574          2.008416        283.429300          3.510481
# 1            3.946793          2.406751        287.750729          3.169654
# 2            4.338222          2.700736        292.000000          2.905885
# 3            4.490000          2.820000        297.357143          2.800000
# 4            4.486831          2.827868        304.535714          3.250000
# ...               ...               ...               ...               ...
# 1370         2.335832          0.236701        274.909621          3.816926
# 1371         2.522798          0.222231        311.090379          3.812667
# 1372         2.704599          0.200732        344.297376          3.808720
# 1373         2.860333          0.174343        368.583090          3.802980
# 1374         2.969100          0.145207        378.000000          3.793342
#
#       T5-S3-AER-P9.1-DO  T5-S3-AER-P9.2-DO  T5-S3-AER-P9.3-DO  \
# 0              0.116945           0.987359           1.528697
# 1              0.119088           0.979271           1.543032
# 2              0.120779           0.967874           1.516184
# 3              0.119089           0.992098           1.523796
# 4              0.114701           0.981230           1.516317
# ...                 ...                ...                ...
# 1370           0.008214           1.214390           1.196488
# 1371           0.007537           1.099349           1.140944
# 1372           0.005778           1.043030           1.113647
# 1373           0.004247           0.980256           1.110408
# 1374           0.003663           0.986136           1.152586
#
#       T5-S3-AER-P9.4-DO  T5-S3-AER-P9-MLSS  T5-S3-SEC-S17-EFF-Flow  \
# 0              1.910033        2602.392372                35437.05
# 1              1.882842        2628.553003                31718.03
# 2              1.907442        2664.045318                33271.28
# 3              1.885284        2814.841079                32689.61
# 4              1.906949        2890.660281                31768.31
# ...                 ...                ...                     ...
# 1370           3.137367        2819.208514                36721.82
# 1371           3.095333        2839.366069                37222.70
# 1372           2.826905        2882.204593                36722.98
# 1373           2.690352        2898.447930                35677.07
# 1374           2.667415        2914.965482                33744.02
#
#       T5-S3-SEC-S17-RSD  T5-S3-SEC-S17-WAS-Flow  T5-S3-SEC-S17-TSS  \
# 0              1.078125               493.04920          10.055807
# 1              1.250000               372.05800           9.181162
# 2              1.421875                19.71519           8.200000
# 3              1.500000               135.55710           6.146734
# 4              1.240741               250.95830           4.600000
# ...                 ...                     ...                ...
# 1370           2.099125               488.36680           3.800000
# 1371           2.196793               488.24490           3.800000
# 1372           2.303207               507.94460           3.800000
# 1373           2.400875               507.56650           3.800000
# 1374           2.472303               515.50630           3.800000
#
#       T5-S3-SEC-S17-SRP  T5-S3-SEC-S17-COD  T5-S3-SEC-S17-CBOD  \
# 0              0.367086          37.608629            2.388263
# 1              0.393472          36.943206            2.354130
# 2              0.429000          36.436248            2.320414
# 3              0.528000          36.113323            2.287161
# 4              0.671000          36.000000            2.254418
# ...                 ...                ...                 ...
# 1370           0.065909          45.504850            1.000000
# 1371           0.065606          44.472515            1.000000
# 1372           0.065050          43.538245            1.000000
# 1373           0.064195          42.861065            1.000000
# 1374           0.063000          42.600000            1.000000
#
#       T5-S3-SEC-S17-TKN  T5-S3-SEC-S17-Ammonia  T5-S3-SEC-S17-Nitrate  \
# 0              1.326713               0.244130              16.453469
# 1              1.305525               0.221023              16.687816
# 2              1.286504               0.200338              16.918477
# 3              1.269720               0.182153              17.145094
# 4              1.255245               0.166548              17.367314
# ...                 ...                    ...                    ...
# 1370           1.344335               0.235407              21.018111
# 1371           1.369793               0.241487              21.062787
# 1372           1.395896               0.247618              21.108029
# 1373           1.422635               0.253792              21.153784
# 1374           1.450000               0.260000              21.200000
#
#       T5-S3-SEC-S17-Nitrite  TP_Exceedance
# 0                  0.253491              0
# 1                  0.227237              0
# 2                  0.203490              0
# 3                  0.182373              0
# 4                  0.164015              0
# ...                     ...            ...
# 1370               0.060043              1
# 1371               0.063142              1
# 1372               0.066335              1
# 1373               0.069621              1
# 1374               0.073000              1
#
# [1375 rows x 25 columns]

# %%
# Covert Time into numerical columns
df['month'] = df['Time'].dt.month
df['week'] = df['Time'].dt.week
df['day'] = df['Time'].dt.day

# %%
# Create a Series for "Time" column
time_column = df["Time"]

# Drop the time column
df.drop('Time', inplace = True, axis = 1)

# %%
df['TP_Exceedance'].value_counts()
# Out:
# 1    1240
# 0     135
# Name: TP_Exceedance, dtype: int64

# %%
# Segment the features from the target
y = df['TP_Exceedance']
X = df.drop(columns="TP_Exceedance")

# %%
# Running and evaluating models
Classification_Models.run_models(X, y)
# Out:
# Logistic Regression (lbfgs)
# Confusion matrix:
#  [[  0   5]
#  [  0 408]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      1.00      0.99       408
#
#     accuracy                           0.99       413
#    macro avg       0.49      0.50      0.50       413
# weighted avg       0.98      0.99      0.98       413
#
#
#
# ----------------------------------------------
# SVC (poly)
#
# Confusion matrix:
#  [[  0   5]
#  [  0 408]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      1.00      0.99       408
#
#     accuracy                           0.99       413
#    macro avg       0.49      0.50      0.50       413
# weighted avg       0.98      0.99      0.98       413
#
#
#
# ----------------------------------------------
# Descision Tree Classification
# Confusion matrix:
#  [[  2   3]
#  [ 47 361]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.04      0.40      0.07         5
#            1       0.99      0.88      0.94       408
#
#     accuracy                           0.88       413
#    macro avg       0.52      0.64      0.50       413
# weighted avg       0.98      0.88      0.92       413
#
#
#
# ----------------------------------------------
# Random Forest Classification
# Confusion matrix:
#  [[  0   5]
#  [  0 408]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      1.00      0.99       408
#
#     accuracy                           0.99       413
#    macro avg       0.49      0.50      0.50       413
# weighted avg       0.98      0.99      0.98       413
#
#
#
# ----------------------------------------------
# Balanced Random Forest Classification
# Confusion matrix:
#  [[  0   5]
#  [ 12 396]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      0.97      0.98       408
#
#     accuracy                           0.96       413
#    macro avg       0.49      0.49      0.49       413
# weighted avg       0.98      0.96      0.97       413
#
#
#
# ----------------------------------------------
# Easy Ensemble Classification
#
# Confusion matrix:
#  [[  0   5]
#  [ 33 375]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      0.92      0.95       408
#
#     accuracy                           0.91       413
#    macro avg       0.49      0.46      0.48       413
# weighted avg       0.97      0.91      0.94       413
#
#
#
# ----------------------------------------------
# Gradient Boosting Classifier
#
# Confusion matrix:
#  [[  0   5]
#  [  0 408]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      1.00      0.99       408
#
#     accuracy                           0.99       413
#    macro avg       0.49      0.50      0.50       413
# weighted avg       0.98      0.99      0.98       413
#
#
#
# ----------------------------------------------
# AdaBoostClassifier
#
# Confusion matrix:
#  [[  0   5]
#  [ 16 392]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      0.96      0.97       408
#
#     accuracy                           0.95       413
#    macro avg       0.49      0.48      0.49       413
# weighted avg       0.98      0.95      0.96       413
#
#
#
# ----------------------------------------------
#                                     Name Accuracy Score  \
# 0            Logistic Regression (lbfgs)         0.9879
# 1                             SVC (poly)         0.9879
# 2          Descision Tree Classification         0.8789
# 3           Random Forest Classification         0.9879
# 4  Balanced Random Forest Classification         0.9588
# 5           Easy Ensemble Classification         0.9080
# 6           Gradient Boosting Classifier         0.9879
# 7                     AdaBoostClassifier         0.9492
#
#   Balanced Accuracy Score  "Exceedance" Predicted Correctly (TP)  \
# 0                  0.5000                                      0
# 1                  0.5000                                      0
# 2                  0.6424                                      2
# 3                  0.5000                                      0
# 4                  0.4853                                      0
# 5                  0.4596                                      0
# 6                  0.5000                                      0
# 7                  0.4804                                      0
#
#    "Exceedance" Predicted Incorrectly (FP)  \
# 0                                        5
# 1                                        5
# 2                                        3
# 3                                        5
# 4                                        5
# 5                                        5
# 6                                        5
# 7                                        5
#
#    "No Exceedance" Predicted Incorrectly (FN)  \
# 0                                           0
# 1                                           0
# 2                                          47
# 3                                           0
# 4                                          12
# 5                                          33
# 6                                           0
# 7                                          16
#
#    "No Exceedance" Predicted Correctly (TN) Actual
# 0                                       408      5
# 1                                       408      5
# 2                                       361      5
# 3                                       408      5
# 4                                       396      5
# 5                                       375      5
# 6                                       408      5
# 7                                       392      5

# %%
# Running and evaluating models with SMOTEENN
Classification_Models.run_models(X, y, True)
# Out:
# Logistic Regression (lbfgs)
# Confusion matrix:
#  [[  5   0]
#  [ 85 323]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.06      1.00      0.11         5
#            1       1.00      0.79      0.88       408
#
#     accuracy                           0.79       413
#    macro avg       0.53      0.90      0.49       413
# weighted avg       0.99      0.79      0.87       413
#
#
#
# ----------------------------------------------
# SVC (poly)
#
# Confusion matrix:
#  [[  0   5]
#  [ 65 343]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      0.84      0.91       408
#
#     accuracy                           0.83       413
#    macro avg       0.49      0.42      0.45       413
# weighted avg       0.97      0.83      0.90       413
#
#
#
# ----------------------------------------------
# Descision Tree Classification
# Confusion matrix:
#  [[  3   2]
#  [ 92 316]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.03      0.60      0.06         5
#            1       0.99      0.77      0.87       408
#
#     accuracy                           0.77       413
#    macro avg       0.51      0.69      0.47       413
# weighted avg       0.98      0.77      0.86       413
#
#
#
# ----------------------------------------------
# Random Forest Classification
# Confusion matrix:
#  [[  0   5]
#  [  5 403]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      0.99      0.99       408
#
#     accuracy                           0.98       413
#    macro avg       0.49      0.49      0.49       413
# weighted avg       0.98      0.98      0.98       413
#
#
#
# ----------------------------------------------
# Balanced Random Forest Classification
# Confusion matrix:
#  [[  0   5]
#  [ 10 398]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      0.98      0.98       408
#
#     accuracy                           0.96       413
#    macro avg       0.49      0.49      0.49       413
# weighted avg       0.98      0.96      0.97       413
#
#
#
# ----------------------------------------------
# Easy Ensemble Classification
#
# Confusion matrix:
#  [[  0   5]
#  [ 11 397]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      0.97      0.98       408
#
#     accuracy                           0.96       413
#    macro avg       0.49      0.49      0.49       413
# weighted avg       0.98      0.96      0.97       413
#
#
#
# ----------------------------------------------
# Gradient Boosting Classifier
#
# Confusion matrix:
#  [[  0   5]
#  [ 12 396]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      0.97      0.98       408
#
#     accuracy                           0.96       413
#    macro avg       0.49      0.49      0.49       413
# weighted avg       0.98      0.96      0.97       413
#
#
#
# ----------------------------------------------
# AdaBoostClassifier
#
# Confusion matrix:
#  [[  0   5]
#  [ 11 397]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         5
#            1       0.99      0.97      0.98       408
#
#     accuracy                           0.96       413
#    macro avg       0.49      0.49      0.49       413
# weighted avg       0.98      0.96      0.97       413
#
#
#
# ----------------------------------------------
#                                                Name Accuracy Score  \
# 0            Logistic Regression (lbfgs) (SMOTEENN)         0.7942
# 1                             SVC (poly) (SMOTEENN)         0.8305
# 2          Descision Tree Classification (SMOTEENN)         0.7724
# 3           Random Forest Classification (SMOTEENN)         0.9758
# 4  Balanced Random Forest Classification (SMOTEENN)         0.9637
# 5           Easy Ensemble Classification (SMOTEENN)         0.9613
# 6           Gradient Boosting Classifier (SMOTEENN)         0.9588
# 7                     AdaBoostClassifier (SMOTEENN)         0.9613
#
#   Balanced Accuracy Score  "Exceedance" Predicted Correctly (TP)  \
# 0                  0.8958                                      5
# 1                  0.4203                                      0
# 2                  0.6873                                      3
# 3                  0.4939                                      0
# 4                  0.4877                                      0
# 5                  0.4865                                      0
# 6                  0.4853                                      0
# 7                  0.4865                                      0
#
#    "Exceedance" Predicted Incorrectly (FP)  \
# 0                                        0
# 1                                        5
# 2                                        2
# 3                                        5
# 4                                        5
# 5                                        5
# 6                                        5
# 7                                        5
#
#    "No Exceedance" Predicted Incorrectly (FN)  \
# 0                                          85
# 1                                          65
# 2                                          92
# 3                                           5
# 4                                          10
# 5                                          11
# 6                                          12
# 7                                          11
#
#    "No Exceedance" Predicted Correctly (TN) Actual
# 0                                       323      5
# 1                                       343      5
# 2                                       316      5
# 3                                       403      5
# 4                                       398      5
# 5                                       397      5
# 6                                       396      5
# 7                                       397      5

# %%
# Running and evaluating Neural Network model
Classification_Models.neural_model(X, y, [100,75], 'linear', 500)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               2700
# _________________________________________________________________
# dense_1 (Dense)              (None, 75)                7575
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 76
# =================================================================
# Total params: 10,351
# Trainable params: 10,351
# Non-trainable params: 0
# _________________________________________________________________
# None
# 13/13 [==============================] - 0s 519us/step - loss: 0.1002 - accuracy: 0.9613
#                                    Name Accuracy Score Model Loss Predicition  \
# 0  Neural Model: [100, 75], linear, 500         0.9613     0.1002           0
#
#   Actual
# 0      5
